# | 27 | P. S. Roy & V. Kukreja (2025) - Vision transformers for rice leaf disease... | `s44447-025-00007-w.pdf` |
# | 28 | Q. Yao et al. (2009) - Application of Support Vector Machine... | `yao2009.pdf` |
# | 29 | T. Gayathri Devi & P. Neelamegam (2019) - Image processing based rice plant leaves... | `gayathridevi2018.pdf` |
# | 30 | Md. J. Hasan et al. (2019) - Rice Disease Identification and Classification... | `hasan2019.pdf` |
# | 31 | F. Jiang et al. (2020) - Image recognition of four rice leaf diseases... | `jiang2020.pdf` |
# | 32 | I. Verawati & R. A. A. Aunurrohim (2024) - Klasifikasi Penyakit Daun Padi... | `Klasifikasi_Penyakit_Daun_Padi_Menggunakan_KNN_den.pdf` |
# | 33 | A. C. Milano (2024) - Klasifikasi Penyakit Daun Padi Menggunakan Model Deep Learning... | `LJ202407181721305954639.pdf` |
# | 34 | H. R. Kappali et al. (2023) - Parametric evaluation of segmentation techniques... | `jae-54-4-1532.pdf` |
# | 35 | R. A. Saputra et al. (2021) - Penerapan Algoritma Convolutional Neural Network... | `Penerapan_Algoritma_Convolutional_Neural.pdf` |
# | 36 | A. Wenda et al. (2020) - Identification of paddy leaf diseases based on texture... | `out.pdf` |
# | 37 | B. K. Hatuwal et al. (2020) - Plant Leaf Disease Recognition Using Random Forest... | `Plant Leaf Disease Recognition Using Random Forest_ KNN_ SVM and CNN.pdf` |
# | 38 | M. E. Pothen & D. M. L. Pai (2020) - Detection of Rice Leaf Diseases Using Image Processing... | `pothen2020.pdf` |
# | 39 | S. Julyani & K. Khairullah (2025) - Pemanfaatan Pengolahan Citra Untuk Deteksi... | `1661-Article Text-7833-1-10-20250618.pdf` |
# | 40 | N. Habibah et al. (2024) - Inventarisasi Hama Penyakit Tanaman Padi... | `3420-Article Text-10380-1-10-20240526.pdf` |
# | 41 | A. Walascha (2022) - Review Artikel: Inventarisasi Jenis Penyakit... | `51.+SMN0248+-+Alvina+Walascha+-+Alvina+Walascha.pdf` |
# | 42 | R. S. Zakaria et al. (2023) - Faktor-Faktor Yang Memengaruhi Risiko Produksi Padi... | `fagb,+1.+Redini+Shaqilha+Zakaria,+dkk+(121-136).pdf` |
# | 43 | D. Das et al. (2020) - Leaf Disease Detection using Support Vector Machine... | `das2020.pdf` |
# | 44 | A. A. Santosa et al. (2023) - Deteksi Penyakit pada Tanaman Padi Menggunakan Pengolahan Citra... | `dd9c1455d8a66446ee1362c0382e7706b3e1.pdf` |
# | 45 | S. R. Shah et al. (2023) - Comparing Inception V3, VGG 16, VGG 19... | `e0d62e72967fd5010088af2461942eac95c6.pdf` |
# | 46 | N. Istiqomah & M. Murinto (2024) - Klasifikasi Penyakit Tanaman Padi Berbasis Citra... | `adminbpi,+3_27314_Galley.pdf` |
# | 47 | E. Murniyasih & L. Suryani (2020) - Penerapan Metode Learning Vector Quantization... | `PENERAPAN_METODE_LEARNING_VECTOR_QUANTIZATION_UNTU.pdf` |
# | 48 | R. Hartono et al. (2025) - A lightweight convolutional neural network... | `9260-26690-1-PB.pdf` |

# %% [markdown]
# |No|Dataset yang Diteliti / Karakteristik|Nomor Sumber Referensi|
# |:--:|:--|:--|
# |1|UCI Machine Learning Repository (3 Kelas Standar)<br>(Bacterial leaf blight, Brown spot, Leaf smut; 40 citra per kelas; Total 120 citra)|3, 5, 14, 15, 16, 24, 32, 35, 38|
# |2|Kaggle (5 Kelas, 4 Sumber Gabungan)<br>(Total 4.342 gambar, 5 kelas, resize 100x100)|1|
# |3|Kaggle (3 Kelas, Sulawesi Tenggara)<br>(3 kelas, 80 gambar per kelas; Total 240 citra, resize 299x299)|2|
# |4|Dataset Kombinasi Private/Website<br>(5 kelas, Total 5.932 gambar, resize 227x227)|4|
# |5|Rice Research Center<br>(3 kelas, 40 gambar per kelas; Total 120 citra)|6|
# |6|Dataset Punjab, Pakistan<br>(3 Kelas: Brown spot 150, BLB 130, False smut 100; Total 380 citra)|7|
# |7|PlantVillage (Multi Tanaman)<br>(54.323 gambar multi-tanaman, termasuk padi)|8, 19, 37|
# |8|Kaggle (3 Kelas: Healthy, BrownSpot, LeafBlast)<br>(Rasio 90:10)|10|
# |9|Dataset Lapangan BRRI (8 Kelas Penyakit/Hama)<br>(Total 1.426 gambar)|11|
# |10|Kaggle (4 Kelas: Hawar Daun, Blas, Tungro, Sehat)<br>(Total 710 data, resize 64x64)|12|
# |11|Annotated Roboflow (3 Kelas)<br>(Brown Spot, Bacterial Blight, Blast; Total 697 gambar)|13|
# |12|Dataset 6000 Citra<br>(3 Kelas: BLB, Rice blast, Tungro; Total 6.000 citra)|18|
# |13|Kaggle Campuran Lapangan (500 Citra)<br>(3 Kelas: Blast, Blight, Tungro; 240 dari Kaggle, 260 dari lapangan)|20|
# |14|Kaggle (3 Kelas: Brown spot, Blast, Blight)<br>(Total 750 citra)|21|
# |15|Dataset 5 Kelas Penyakit<br>(150 data latih, 30 data uji; Total 180 citra)|23|
# |16|Dataset Private Indonesia<br>(5 Kelas Penyakit; Total 1.275 citra, divalidasi 9 ahli)|25|
# |17|Kaggle (6 Kelas)<br>(Total 2.627 gambar)|26|
# |18|Dataset Multi-task Vision Transformer<br>(10 jenis penyakit, 3 tingkat keparahan; Total 3.345 gambar)|27|
# |19|Dataset Lapangan Yao et al. (2009)<br>(3 penyakit; 72 sampel per penyakit; Total 216 citra)|28|
# |20|Aduthurai Research Center & IRRI (6 Kelas)<br>(Total 500 citra, 6 kelas)|29|
# |21|Dataset Hybrid Sawah & Online (9 Jenis Penyakit)<br>(Total 1.080 citra)|30|
# |22|Dataset Besar Jiang et al.<br>(5 Kelas: Healthy, Blast, Bacterial Spot, Streak Leaf Spot, Sheath Blight; Total 8.911 citra (termasuk augmentasi))|31|
# |23|Kaggle (4 Kelas: Healthy, LeafBlast, Hispa, BrownSpot)<br>(Total 3.355 citra)|33|
# |24|Kaggle dan Petani Lokal (3 Kelas)<br>(BLB, Brown spot, Leaf smut)|34|
# |25|Dataset 100 Citra Daun Berpenyakit<br>(Blast, Brown Spot, Narrow Brown Spot)|36|
# |26|PlantVillage (Tomat)<br>(7 penyakit + 1 sehat; Total 14.000 citra)|43|
# |27|Dataset Large Scale CNN<br>(4 Kelas: BLB, Brown spot, Leaf smut, Healthy; Total 16.000 citra)|44|
# |28|Kaggle (2 Kelas: Leaf Blast dan Sehat)<br>(Total 2.000 gambar)|45|
# |29|Dataset 800 Citra CNN<br>(4 Kelas: BLB, Blas, Brown spot, Tungro; Total 800 citra)|46|
# |30|Dataset LVQ (Bercak Daun)<br>(3 jenis penyakit, Total 65 data)|47|
# |31|Kaggle: "Rice Leaf Diseases Dataset" (8 Kelas)<br>(8 kelas penyakit/hama; 1.886 citra asli, oversampled menjadi 2.800)|48|
# |32|Kaggle (4 Kelas: Brown Spot, Blast, Hispa, Sehat)<br>(Total 480 gambar)|17|
# |33|Data Gejala dan Penyakit (Sistem Pakar)<br>(13 penyakit, 43 gejala, dari wawancara pakar)|9, 22|
# |34|Studi Literatur / Review / Observasi Lapangan Kualitatif|39, 40, 41, 42|
